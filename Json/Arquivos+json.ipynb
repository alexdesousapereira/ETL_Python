# %% [markdown]
# fonte: https://dados.gov.br/dataset/dados-abertos-de-recursos-humanos-da-aeb/resource/4ed1acb6-e403-4be5-8c8c-90b0248673d4?inner_span=True

# %% [markdown]
# # Bibliotecas

# %%
import pandas as pd
import json
from google.oauth2 import service_account

# %% [markdown]
# ## Extração dos dados

# %%
f = open('tb_acoes.json', encoding='utf-8')
data = json.load(f)

# %%
data
# Out:
# [{'id_acao': 1,
#   'nome_acao': 'Assistência Pré-escolar aos Dependentes dos Servidores e Empregados'},
#  {'id_acao': 2,
#   'nome_acao': 'Assistência Médica e Odontológica aos Servidores, Empregados e seus Dependentes'},
#  {'id_acao': 3, 'nome_acao': 'Auxílio Transporte aos Servidores e Empregados'},
#  {'id_acao': 4,
#   'nome_acao': 'Auxílio Alimentação aos Servidores e Empregados'},
#  {'id_acao': 5, 'nome_acao': 'Desenvolvimento de Satélites'},
#  {'id_acao': 6,
#   'nome_acao': 'Desenvolvimento de Veículos Lançadores de Satélites'},
#  {'id_acao': 7, 'nome_acao': 'Desenvolvimento de Foguetes de Sondagem'},
#  {'id_acao': 8,
#   'nome_acao': 'Pesquisa e Desenvolvimento em Ciências e Tecnologias Espaciais'},
#  {'id_acao': 9,
#   'nome_acao': 'Capacitação de Recursos Humanos para a Área Espacial'},
#  {'id_acao': 10,
#   'nome_acao': 'Regulamentações, Licenças e Certificações Espaciais'},
#  {'id_acao': 11,
# ...

# %%
acoes = pd.read_json('tb_acoes.json')

# %%
acoes.head()
# Out:
#    id_acao                                          nome_acao
# 0        1  Assistência Pré-escolar aos Dependentes dos Se...
# 1        2  Assistência Médica e Odontológica aos Servidor...
# 2        3     Auxílio Transporte aos Servidores e Empregados
# 3        4    Auxílio Alimentação aos Servidores e Empregados
# 4        5                       Desenvolvimento de Satélites

# %%
anos = pd.read_json('tb_anos.json')

# %%
anos.head()
# Out:
#    id_ano  data_ano
# 0       1      2000
# 1       2      2001
# 2       3      2002
# 3       4      2003
# 4       5      2004

# %%
orcamentos = pd.read_json('tb_orcamentos.json')

# %%
orcamentos.head()
# Out:
#    id_orcamento  dotacao_atual  empenhado  liquidado     pago  fk_acao  \
# 0             1          12000       8351       8351     8351        1
# 1             2          42750      39577      39577    39577        2
# 2             3          26000      25461      25461    25461        3
# 3             4          76755      68730      68730    68730        4
# 4             5        5882850    5191526    5191526  3611488        5
#
#    fk_programa  fk_unidade  fk_ano
# 0            1           1       1
# 1            2           1       1
# 2            2           1       1
# 3            2           1       1
# 4            3           1       1

# %%
programas = pd.read_json('tb_programas.json')

# %%
programas.head()
# Out:
#    id_programa                                 nome_programa
# 0            1                             Atenção À Criança
# 1            2                    Assistência ao Trabalhador
# 2            3       Nacional de Atividades Espaciais - Pnae
# 3            4                          Apoio Administrativo
# 4            5  Gestão da Política de Comunicação de Governo

# %%
unidades_orc = pd.read_json('tb_unidades_orcamentarias.json')

# %%
unidades_orc.head()
# Out:
#    id_unidade                                       nome_unidade
# 0           1                        Agência Espacial Brasileira
# 1           2  Ministério da Ciência, Tecnologia, Inovações e...

# %% [markdown]
# ## Transformação

# %%
orcamentos.head()
# Out:
#    id_orcamento  dotacao_atual  empenhado  liquidado     pago  fk_acao  \
# 0             1          12000       8351       8351     8351        1
# 1             2          42750      39577      39577    39577        2
# 2             3          26000      25461      25461    25461        3
# 3             4          76755      68730      68730    68730        4
# 4             5        5882850    5191526    5191526  3611488        5
#
#    fk_programa  fk_unidade  fk_ano
# 0            1           1       1
# 1            2           1       1
# 2            2           1       1
# 3            2           1       1
# 4            3           1       1

# %%
orcamentos = orcamentos.merge(acoes,
                                left_on='fk_acao',
                                right_on='id_acao',
                                how = 'left')

# %%
orcamentos.head()
# Out:
#    id_orcamento  dotacao_atual  empenhado  liquidado     pago  fk_acao  \
# 0             1          12000       8351       8351     8351        1
# 1             2          42750      39577      39577    39577        2
# 2             3          26000      25461      25461    25461        3
# 3             4          76755      68730      68730    68730        4
# 4             5        5882850    5191526    5191526  3611488        5
#
#    fk_programa  fk_unidade  fk_ano  id_acao  \
# 0            1           1       1        1
# 1            2           1       1        2
# 2            2           1       1        3
# 3            2           1       1        4
# 4            3           1       1        5
#
#                                            nome_acao
# 0  Assistência Pré-escolar aos Dependentes dos Se...
# 1  Assistência Médica e Odontológica aos Servidor...
# 2     Auxílio Transporte aos Servidores e Empregados
# 3    Auxílio Alimentação aos Servidores e Empregados
# ...

# %%
orcamentos.drop(columns=['id_acao', 'fk_acao'],inplace=True)

# %%
orcamentos = orcamentos.merge(programas,
                                left_on='fk_programa',
                                right_on='id_programa',
                                   how = 'left')

# %%
orcamentos.drop(columns=['id_programa', 'fk_programa'],inplace=True)

# %%
orcamentos.head()
# Out:
#    id_orcamento  dotacao_atual  empenhado  liquidado     pago  fk_unidade  \
# 0             1          12000       8351       8351     8351           1
# 1             2          42750      39577      39577    39577           1
# 2             3          26000      25461      25461    25461           1
# 3             4          76755      68730      68730    68730           1
# 4             5        5882850    5191526    5191526  3611488           1
#
#    fk_ano                                          nome_acao  \
# 0       1  Assistência Pré-escolar aos Dependentes dos Se...
# 1       1  Assistência Médica e Odontológica aos Servidor...
# 2       1     Auxílio Transporte aos Servidores e Empregados
# 3       1    Auxílio Alimentação aos Servidores e Empregados
# 4       1                       Desenvolvimento de Satélites
#
#                              nome_programa
# 0                        Atenção À Criança
# 1               Assistência ao Trabalhador
# ...

# %%
orcamentos = orcamentos.merge(unidades_orc,
                                left_on='fk_unidade',
                                right_on='id_unidade',
                                how = 'left')

# %%
orcamentos.drop(columns=['id_unidade', 'fk_unidade'],inplace=True)

# %%
orcamentos = orcamentos.merge(anos,
                                left_on='fk_ano',
                                right_on='id_ano',
                                how = 'left')

# %%
orcamentos.drop(columns=['id_ano', 'fk_ano'],inplace=True)

# %%
orcamentos.head()
# Out:
#    id_orcamento  dotacao_atual  empenhado  liquidado     pago  fk_unidade  \
# 0             1          12000       8351       8351     8351           1
# 1             2          42750      39577      39577    39577           1
# 2             3          26000      25461      25461    25461           1
# 3             4          76755      68730      68730    68730           1
# 4             5        5882850    5191526    5191526  3611488           1
#
#                                            nome_acao  \
# 0  Assistência Pré-escolar aos Dependentes dos Se...
# 1  Assistência Médica e Odontológica aos Servidor...
# 2     Auxílio Transporte aos Servidores e Empregados
# 3    Auxílio Alimentação aos Servidores e Empregados
# 4                       Desenvolvimento de Satélites
#
#                              nome_programa  id_unidade  \
# 0                        Atenção À Criança           1
# 1               Assistência ao Trabalhador           1
# ...

# %%
orcamentos.isnull().sum()
# Out:
# id_orcamento     0
# dotacao_atual    0
# empenhado        0
# liquidado        0
# pago             0
# fk_unidade       0
# nome_acao        0
# nome_programa    0
# id_unidade       0
# nome_unidade     0
# data_ano         0
# dtype: int64

# %%
orcamentos.shape
# Out:
# (438, 11)

# %%
orcamentos.dtypes
# Out:
# id_orcamento      int64
# dotacao_atual     int64
# empenhado         int64
# liquidado         int64
# pago              int64
# fk_unidade        int64
# nome_acao        object
# nome_programa    object
# id_unidade        int64
# nome_unidade     object
# data_ano          int64
# dtype: object

# %%
orcamentos[['dotacao_atual',
           'empenhado',
           'liquidado',
           'pago']].describe().round(2)
# Out:
#        dotacao_atual     empenhado    liquidado         pago
# count   4.380000e+02  4.380000e+02       438.00       438.00
# mean    8.879558e+06  7.986011e+06   4537643.90   3913902.63
# std     1.821931e+07  1.664496e+07   9919315.50   8634789.85
# min     1.000000e+03  0.000000e+00         0.00         0.00
# 25%     1.004100e+05  5.975150e+04     41058.75     40286.50
# 50%     1.600000e+06  1.202893e+06    756336.50    573080.50
# 75%     7.465994e+06  7.153428e+06   4693673.25   3569674.50
# max     1.405779e+08  1.119863e+08  78480901.00  56585593.00

# %%
orcamentos.data_ano.value_counts()
# Out:
# 2012    37
# 2005    32
# 2006    31
# 2008    31
# 2011    30
# 2007    30
# 2010    29
# 2009    29
# 2001    19
# 2002    18
# 2004    18
# 2000    17
# 2003    16
# 2015    16
# 2016    16
# 2017    16
# 2014    14
# 2013    13
# 2018    13
# 2019    13
# Name: data_ano, dtype: int64

# %% [markdown]
# ## Carregamento dos Dados

# %%
credentials = service_account.Credentials.from_service_account_file(filename='/home/alex/apps/drivers/ContaServicoBigQuery.json', 
                                                                    scopes=["https://www.googleapis.com/auth/cloud-platform"])

# %%
orcamentos.to_gbq(credentials=credentials, 
                destination_table='curso_etl.etl_json', 
                if_exists='replace')
