# %% [markdown]
# link: https://academic.udayton.edu/kissock/http/Weather/source.htm

# %% [markdown]
# ### Bibliotecas

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from google.oauth2 import service_account

# %% [markdown]
# ### Extração

# %%
df = pd.read_csv('NYNEWYOR.txt', delim_whitespace=True, header=None)

# %%
df
# Out:
#       0   1     2     3
# 0     1   1  1995  44.0
# 1     1   2  1995  41.8
# 2     1   3  1995  28.1
# 3     1   4  1995  31.7
# 4     1   5  1995  21.3
# ...  ..  ..   ...   ...
# 9260  5   9  2020  42.2
# 9261  5  10  2020  50.3
# 9262  5  11  2020  55.7
# 9263  5  12  2020  51.1
# 9264  5  13  2020  51.8
#
# [9265 rows x 4 columns]

# %%
df.rename(columns={0: 'mes', 
                   1: 'dia', 
                   2: 'ano', 
                   3: 'temperatura'}, 
          inplace=True)

# %%
df
# Out:
#       mes  dia   ano  temperatura
# 0       1    1  1995         44.0
# 1       1    2  1995         41.8
# 2       1    3  1995         28.1
# 3       1    4  1995         31.7
# 4       1    5  1995         21.3
# ...   ...  ...   ...          ...
# 9260    5    9  2020         42.2
# 9261    5   10  2020         50.3
# 9262    5   11  2020         55.7
# 9263    5   12  2020         51.1
# 9264    5   13  2020         51.8
#
# [9265 rows x 4 columns]

# %%
df.dtypes
# Out:
# mes              int64
# dia              int64
# ano              int64
# temperatura    float64
# dtype: object

# %% [markdown]
# ### Transformação

# %%
df.count()
# Out:
# mes            9265
# dia            9265
# ano            9265
# temperatura    9265
# dtype: int64

# %%
df.temperatura.value_counts()
# Out:
# 77.5    35
# 76.3    32
# 73.8    32
# 75.0    31
# 76.4    30
#         ..
# 8.5      1
# 92.0     1
# 10.9     1
# 88.5     1
# 88.8     1
# Name: temperatura, Length: 765, dtype: int64

# %%
df[df.temperatura == -99]
# Out:
#       mes  dia   ano  temperatura
# 492     5    7  1996        -99.0
# 514     5   29  1996        -99.0
# 517     6    1  1996        -99.0
# 518     6    2  1996        -99.0
# 522     6    6  1996        -99.0
# 1453   12   24  1998        -99.0
# 1454   12   25  1998        -99.0
# 1459   12   30  1998        -99.0
# 1460   12   31  1998        -99.0
# 1470    1   10  1999        -99.0
# 2725    6   18  2002        -99.0
# 2726    6   19  2002        -99.0
# 2727    6   20  2002        -99.0
# 2728    6   21  2002        -99.0
# 2806    9    7  2002        -99.0
# 2934    1   13  2003        -99.0
# 2981    3    1  2003        -99.0
# 4622    8   28  2007        -99.0
# 5015    9   24  2008        -99.0
# 5212    4    9  2009        -99.0

# %%
plt.figure(figsize=(30, 10))
sns.lineplot(df.index, df.temperatura)
plt.show()
# Out:
# /home/alex/.virtualenvs/etl/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.describe()
# Out:
#                mes          dia          ano  temperatura
# count  9265.000000  9265.000000  9265.000000  9265.000000
# mean      6.468322    15.715812  2007.187372    55.640615
# std       3.457036     8.800739     7.325302    18.501274
# min       1.000000     1.000000  1995.000000   -99.000000
# 25%       3.000000     8.000000  2001.000000    42.200000
# 50%       6.000000    16.000000  2007.000000    56.000000
# 75%       9.000000    23.000000  2014.000000    71.300000
# max      12.000000    31.000000  2020.000000    93.700000

# %%
df.temperatura = df.temperatura.replace(-99, np.nan)

# %%
df[df.temperatura == -99]
# Out:
# Empty DataFrame
# Columns: [mes, dia, ano, temperatura]
# Index: []

# %%
df.head()
# Out:
#    mes  dia   ano  temperatura
# 0    1    1  1995         44.0
# 1    1    2  1995         41.8
# 2    1    3  1995         28.1
# 3    1    4  1995         31.7
# 4    1    5  1995         21.3

# %%
df['elemento_anterior'] = df.temperatura.shift(1)

# %%
df['elemento_posterior'] = df.temperatura.shift(-1)

# %%
df.head()
# Out:
#    mes  dia   ano  temperatura  elemento_anterior  elemento_posterior
# 0    1    1  1995         44.0                NaN                41.8
# 1    1    2  1995         41.8               44.0                28.1
# 2    1    3  1995         28.1               41.8                31.7
# 3    1    4  1995         31.7               28.1                21.3
# 4    1    5  1995         21.3               31.7                27.9

# %%
df['back_fill'] = df.temperatura.bfill(axis=0)

# %%
df['forward_fill'] = df.temperatura.ffill(axis=0)

# %%
df.head()
# Out:
#    mes  dia   ano  temperatura  elemento_anterior  elemento_posterior  \
# 0    1    1  1995         44.0                NaN                41.8
# 1    1    2  1995         41.8               44.0                28.1
# 2    1    3  1995         28.1               41.8                31.7
# 3    1    4  1995         31.7               28.1                21.3
# 4    1    5  1995         21.3               31.7                27.9
#
#    back_fill  forward_fill
# 0       44.0          44.0
# 1       41.8          41.8
# 2       28.1          28.1
# 3       31.7          31.7
# 4       21.3          21.3

# %%
df[df.temperatura.notnull() == False]
# Out:
#       mes  dia   ano  temperatura  elemento_anterior  elemento_posterior  \
# 492     5    7  1996          NaN               50.2                48.5
# 514     5   29  1996          NaN               57.5                57.4
# 517     6    1  1996          NaN               58.5                 NaN
# 518     6    2  1996          NaN                NaN                59.7
# 522     6    6  1996          NaN               65.9                69.6
# 1453   12   24  1998          NaN               24.3                 NaN
# 1454   12   25  1998          NaN                NaN                30.5
# 1459   12   30  1998          NaN               39.0                 NaN
# 1460   12   31  1998          NaN                NaN                25.9
# 1470    1   10  1999          NaN               37.5                24.8
# 2725    6   18  2002          NaN               70.3                 NaN
# 2726    6   19  2002          NaN                NaN                 NaN
# 2727    6   20  2002          NaN                NaN                 NaN
# 2728    6   21  2002          NaN                NaN                77.4
# 2806    9    7  2002          NaN               70.7                72.9
# 2934    1   13  2003          NaN               28.6                26.4
# 2981    3    1  2003          NaN               31.0                37.3
# 4622    8   28  2007          NaN               76.8                77.6
# 5015    9   24  2008          NaN               61.8                61.9
# 5212    4    9  2009          NaN               42.0                51.4
#
#       back_fill  forward_fill
# 492        48.5          50.2
# 514        57.4          57.5
# 517        59.7          58.5
# 518        59.7          58.5
# 522        69.6          65.9
# 1453       30.5          24.3
# 1454       30.5          24.3
# 1459       25.9          39.0
# 1460       25.9          39.0
# 1470       24.8          37.5
# 2725       77.4          70.3
# 2726       77.4          70.3
# 2727       77.4          70.3
# 2728       77.4          70.3
# 2806       72.9          70.7
# 2934       26.4          28.6
# 2981       37.3          31.0
# 4622       77.6          76.8
# 5015       61.9          61.8
# 5212       51.4          42.0

# %%
df['substituicao'] = (df.temperatura.shift(1).ffill(axis=0) + df.temperatura.shift(-1).bfill(axis=0))/2

# %%
df.head()
# Out:
#    mes  dia   ano  temperatura  elemento_anterior  elemento_posterior  \
# 0    1    1  1995         44.0                NaN                41.8
# 1    1    2  1995         41.8               44.0                28.1
# 2    1    3  1995         28.1               41.8                31.7
# 3    1    4  1995         31.7               28.1                21.3
# 4    1    5  1995         21.3               31.7                27.9
#
#    back_fill  forward_fill  substituicao
# 0       44.0          44.0           NaN
# 1       41.8          41.8         36.05
# 2       28.1          28.1         36.75
# 3       31.7          31.7         24.70
# 4       21.3          21.3         29.80

# %%
df[df.temperatura.notnull() == False]
# Out:
#       mes  dia   ano  temperatura  elemento_anterior  elemento_posterior  \
# 492     5    7  1996          NaN               50.2                48.5
# 514     5   29  1996          NaN               57.5                57.4
# 517     6    1  1996          NaN               58.5                 NaN
# 518     6    2  1996          NaN                NaN                59.7
# 522     6    6  1996          NaN               65.9                69.6
# 1453   12   24  1998          NaN               24.3                 NaN
# 1454   12   25  1998          NaN                NaN                30.5
# 1459   12   30  1998          NaN               39.0                 NaN
# 1460   12   31  1998          NaN                NaN                25.9
# 1470    1   10  1999          NaN               37.5                24.8
# 2725    6   18  2002          NaN               70.3                 NaN
# 2726    6   19  2002          NaN                NaN                 NaN
# 2727    6   20  2002          NaN                NaN                 NaN
# 2728    6   21  2002          NaN                NaN                77.4
# 2806    9    7  2002          NaN               70.7                72.9
# 2934    1   13  2003          NaN               28.6                26.4
# 2981    3    1  2003          NaN               31.0                37.3
# 4622    8   28  2007          NaN               76.8                77.6
# 5015    9   24  2008          NaN               61.8                61.9
# 5212    4    9  2009          NaN               42.0                51.4
#
#       back_fill  forward_fill  substituicao
# 492        48.5          50.2         49.35
# 514        57.4          57.5         57.45
# 517        59.7          58.5         59.10
# 518        59.7          58.5         59.10
# 522        69.6          65.9         67.75
# 1453       30.5          24.3         27.40
# 1454       30.5          24.3         27.40
# 1459       25.9          39.0         32.45
# 1460       25.9          39.0         32.45
# 1470       24.8          37.5         31.15
# 2725       77.4          70.3         73.85
# 2726       77.4          70.3         73.85
# 2727       77.4          70.3         73.85
# 2728       77.4          70.3         73.85
# 2806       72.9          70.7         71.80
# 2934       26.4          28.6         27.50
# 2981       37.3          31.0         34.15
# 4622       77.6          76.8         77.20
# 5015       61.9          61.8         61.85
# 5212       51.4          42.0         46.70

# %%
df.temperatura = np.where(df.temperatura.notnull() == False, 
                          df.substituicao, 
                          df.temperatura)

# %%
df
# Out:
#       mes  dia   ano  temperatura  elemento_anterior  elemento_posterior  \
# 0       1    1  1995         44.0                NaN                41.8
# 1       1    2  1995         41.8               44.0                28.1
# 2       1    3  1995         28.1               41.8                31.7
# 3       1    4  1995         31.7               28.1                21.3
# 4       1    5  1995         21.3               31.7                27.9
# ...   ...  ...   ...          ...                ...                 ...
# 9260    5    9  2020         42.2               53.1                50.3
# 9261    5   10  2020         50.3               42.2                55.7
# 9262    5   11  2020         55.7               50.3                51.1
# 9263    5   12  2020         51.1               55.7                51.8
# 9264    5   13  2020         51.8               51.1                 NaN
#
#       back_fill  forward_fill  substituicao
# 0          44.0          44.0           NaN
# 1          41.8          41.8         36.05
# 2          28.1          28.1         36.75
# 3          31.7          31.7         24.70
# 4          21.3          21.3         29.80
# ...         ...           ...           ...
# 9260       42.2          42.2         51.70
# 9261       50.3          50.3         48.95
# 9262       55.7          55.7         50.70
# 9263       51.1          51.1         53.75
# 9264       51.8          51.8           NaN
#
# [9265 rows x 9 columns]

# %%
df[df.temperatura.notnull() == False]
# Out:
# Empty DataFrame
# Columns: [mes, dia, ano, temperatura, elemento_anterior, elemento_posterior, back_fill, forward_fill, substituicao]
# Index: []

# %%
plt.figure(figsize=(30, 10))
sns.lineplot(df.index, df.temperatura)
plt.show()
# Out:
# /home/alex/.virtualenvs/etl/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.describe()
# Out:
#                mes          dia          ano  temperatura  elemento_anterior  \
# count  9265.000000  9265.000000  9265.000000  9265.000000        9244.000000
# mean      6.468322    15.715812  2007.187372    55.968538          55.975606
# std       3.457036     8.800739     7.325302    17.067751          17.065067
# min       1.000000     1.000000  1995.000000     8.300000           8.300000
# 25%       3.000000     8.000000  2001.000000    42.200000          42.200000
# 50%       6.000000    16.000000  2007.000000    56.100000          56.100000
# 75%       9.000000    23.000000  2014.000000    71.300000          71.300000
# max      12.000000    31.000000  2020.000000    93.700000          93.700000
#
#        elemento_posterior    back_fill  forward_fill  substituicao
# count         9244.000000  9265.000000   9265.000000   9263.000000
# mean            55.976450    55.969768     55.967307     55.970436
# std             17.064668    17.071775     17.065213     16.596262
# min              8.300000     8.300000      8.300000     13.750000
# 25%             42.200000    42.200000     42.200000     42.250000
# 50%             56.100000    56.100000     56.100000     56.000000
# 75%             71.300000    71.300000     71.300000     71.300000
# max             93.700000    93.700000     93.700000     90.650000

# %%
df['temperatua_celsius'] = (df.temperatura - 32)*(5/9)

# %%
df.describe()
# Out:
#                mes          dia          ano  temperatura  elemento_anterior  \
# count  9265.000000  9265.000000  9265.000000  9265.000000        9244.000000
# mean      6.468322    15.715812  2007.187372    55.968538          55.975606
# std       3.457036     8.800739     7.325302    17.067751          17.065067
# min       1.000000     1.000000  1995.000000     8.300000           8.300000
# 25%       3.000000     8.000000  2001.000000    42.200000          42.200000
# 50%       6.000000    16.000000  2007.000000    56.100000          56.100000
# 75%       9.000000    23.000000  2014.000000    71.300000          71.300000
# max      12.000000    31.000000  2020.000000    93.700000          93.700000
#
#        elemento_posterior    back_fill  forward_fill  substituicao  \
# count         9244.000000  9265.000000   9265.000000   9263.000000
# mean            55.976450    55.969768     55.967307     55.970436
# std             17.064668    17.071775     17.065213     16.596262
# min              8.300000     8.300000      8.300000     13.750000
# 25%             42.200000    42.200000     42.200000     42.250000
# 50%             56.100000    56.100000     56.100000     56.000000
# 75%             71.300000    71.300000     71.300000     71.300000
# max             93.700000    93.700000     93.700000     90.650000
#
#        temperatua_celsius
# count         9265.000000
# mean            13.315854
# std              9.482084
# min            -13.166667
# 25%              5.666667
# 50%             13.388889
# 75%             21.833333
# max             34.277778

# %% [markdown]
# ### Carregamento

# %%
credentials = service_account.Credentials.from_service_account_file(filename='/home/alex/apps/drivers/ContaServicoBigQuery.json', 
                                                                    scopes=['https://www.googleapis.com/auth/cloud-platform'])

# %%
df.to_gbq(credentials=credentials, 
          destination_table='curso_etl.etl_txt')
